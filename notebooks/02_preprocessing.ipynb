# %% [markdown]
# # 02 - Preprocessing & Feature Engineering

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from src.preprocessing import load_raw_dataset, preprocess_dataframe

DATA_PATH = os.path.join('..', 'data', 'raw', 'fake_job_postings.csv')
df = load_raw_dataset(DATA_PATH)
df_processed = preprocess_dataframe(df)
df_processed[['text', 'text_length', 'has_salary_range', 'fraudulent']].head()

# %%
OUT_PATH = os.path.join('..', 'data', 'processed', 'processed_job_postings.csv')
df_processed.to_csv(OUT_PATH, index=False)
print(f'Saved processed dataset to {OUT_PATH}')
